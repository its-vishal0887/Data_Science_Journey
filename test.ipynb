# %%
#this is cell 
1+2
# Out:
# 3

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # comments
#
# # single line(using #)
# # multi-Line Cmt("", '', ''' ''')
#
# '''Hi my name is
#     vishal '''
#
# """Hi my name is Vishal"""
#
# 'Hi My name is Vishal'

# %%
## Basic Syntax Rules In Python
## Case sensitivity- Python is case sensitive
