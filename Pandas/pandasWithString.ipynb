# %%
import pandas as pd

# %%
s = pd.Series(['Cat', 'Mat', None, 'Sat'])
s.str.startswith('C')
# Out:
# 0     True
# 1    False
# 2     None
# 3    False
# dtype: object

# %%
df = pd.read_csv('/content/titanic.csv')
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.lower()
df['Name'].str.capitalize()
df['Name'].str.title()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#length
df['Name'].str.len()
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
df['Name'].str.len().max()
# Out:
# 82

# %%
df['Name'][df['Name'].str.len() == 82].values[0]
# Out:
# 'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %%
df['Name'].str.strip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df['LastName'] = df['Name'].str.split(',', n=1).str.get(0)
df[['Title', 'Name']] = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ', n=1, expand=True)

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass         Name   Sex   Age  SibSp  Parch  \
# 0            1         0       3  Owen Harris  male  22.0      1      0
#
#       Ticket  Fare Cabin Embarked LastName Title
# 0  A/5 21171  7.25   NaN        S   Braund   Mr.

# %%
df['Title'] = df['Title'].str.replace('Mr', 'Miss.')
df['Title'] = df['Title'].str.replace('Mlle', 'Miss')
df['Title'].value_counts()
# Out:
# Title
# Miss..       517
# Miss.        184
# Miss.s.      125
# Master.       40
# Dr.            7
# Rev.           6
# Col.           2
# Major.         2
# Mme.           1
# Don.           1
# Lady.          1
# Ms.            1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
df['Title'].value_counts()
# Out:
# Title
# Miss..       517
# Miss.        184
# Miss.s.      125
# Master.       40
# Dr.            7
# Rev.           6
# Col.           2
# Major.         2
# Mme.           1
# Don.           1
# Lady.          1
# Ms.            1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
#filltering
#startswith()
df[df['Name'].str.startswith('A')]

#endswith()
df[df['Name'].str.endswith('A')]

#we also try isdigit() ,etc.
# Out:
#      PassengerId  Survived  Pclass      Name     Sex  Age  SibSp  Parch  \
# 64            65         0       1  Albert A    male  NaN      0      0
# 303          304         1       2    Nora A  female  NaN      0      0
#
#        Ticket     Fare Cabin Embarked LastName   Title
# 64   PC 17605  27.7208   NaN        C  Stewart  Miss..
# 303    226593  12.3500  E101        Q    Keane   Miss.

# %%
#Advance Filtering
# applying regex(regular expression)
# search john -> both cases
df[df['Name'].str.contains('john', case=False)].head()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 1          John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 41   William John Robert (Dorothy Ann Wonnacott)  female  27.0      1      0
# 45                                  William John    male   NaN      0      0
# 98                       John T (Ada Julia Bone)  female  34.0      0      1
# 112                                   David John    male  22.0      0      0
#
#               Ticket     Fare Cabin Embarked LastName    Title
# 1           PC 17599  71.2833   C85        C  Cumings  Miss.s.
# 41             11668  21.0000   NaN        S   Turpin  Miss.s.
# 45   S.C./A.4. 23567   8.0500   NaN        S   Rogers   Miss..
# ...
