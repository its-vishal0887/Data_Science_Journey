# %%
import numpy as np
import pandas as pd

# %%
#list ko use kar ke kaise series bana sakte hai

# %%
country = ['india', 'austrelia','china', 'nepal']

pd.Series(country)
# Out:
# 0        india
# 1    austrelia
# 2        china
# 3        nepal
# dtype: object

# %%
runs = [13,56,87,96,100,102]
pd.Series(runs)
# Out:
# 0     13
# 1     56
# 2     87
# 3     96
# 4    100
# 5    102
# dtype: int64

# %%
#index=
subject = ['marathi', 'hindi','english','maths','science']
marks = [99,89,78,98,95]
h = pd.Series(marks, index=subject)

h.size
# Out:
# 5

# %%
#Name

pd.Series(marks, index= subject, name = 'Vishal ke marks')
# Out:
# marathi    99
# hindi      89
# english    78
# maths      98
# science    95
# Name: Vishal ke marks, dtype: int64

# %%
dic = {
    'maths':86,
    'marathi':78,
    'english':98,
    'hindi':100,
    'Science':87
}

k = pd.Series(dic, name = "vishal ke marks")
k.name
# Out:
# 'vishal ke marks'

# %%
k.dtype
k.name
k.is_unique
k.index
k.values
# Out:
# array([ 86,  78,  98, 100,  87])

# %%
s = pd.read_csv("bollywood.csv", index_col='SlNo')
s.drop(["ReleaseDate","ReleaseTime", "Genre","YoutubeLikes","YoutubeDislikes"], axis=1, inplace=True)
n = s
n
n.head()

n.tail()
# Out:
#                       MovieName  Budget  BoxOfficeCollection  YoutubeViews
# SlNo
# 145             DumLagaKeHaisha      15                30.00       3250917
# 146                        NH10      13                32.10       5592977
# 147   DilliwaliZaalimGirlfriend      32                12.00       2316047
# 148                    Hunterrr       5                11.89       4674795
# 149               Kochadaiiyaan     150               120.00       4740727

# %%
x = pd.read_csv("/content/kohli_ipl.csv", index_col='match_no')
x
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
#Random Row Ko generate krega .sample(NUM)
n.sample()
# Out:
#      MovieName  Budget  BoxOfficeCollection  YoutubeViews
# SlNo
# 52       Aatma       8                 8.78        841891

# %%
#by defult top 5 head ko return krega .head(num)
n.head()
# Out:
#             MovieName  Budget  BoxOfficeCollection  YoutubeViews
# SlNo
# 1             2States      36               104.00       8576361
# 2          TableNo.21      10                12.00       1087320
# 3     AmitSahniKiList      10                 4.00        572336
# 4     RajdhaniExpress       7                 0.35         42626
# 5         BobbyJasoos      18                10.80       3113427

# %%
#by defult down 5 ko return krega .tail(num)
n.tail()
# Out:
#                       MovieName  Budget  BoxOfficeCollection  YoutubeViews
# SlNo
# 145             DumLagaKeHaisha      15                30.00       3250917
# 146                        NH10      13                32.10       5592977
# 147   DilliwaliZaalimGirlfriend      32                12.00       2316047
# 148                    Hunterrr       5                11.89       4674795
# 149               Kochadaiiyaan     150               120.00       4740727

# %%
#ye frequency count ke kaam ata hai .value_counts('ColName')
n.value_counts('Budget')
# Out:
# Budget
# 10     12
# 15     10
# 12      9
# 5       9
# 30      9
# 35      8
# 50      7
# 24      5
# 40      5
# 18      4
# 25      4
# 20      4
# 4       4
# 16      3
# 2       3
# 11      3
# 7       3
# 75      3
# 60      3
# 27      3
# 100     2
# 36      2
# 6       2
# 8       2
# 90      2
# 85      2
# 31      2
# 21      2
# 22      2
# 3       1
# 14      1
# 13      1
# 9       1
# 19      1
# 33      1
# 32      1
# 28      1
# 23      1
# 26      1
# 29      1
# 48      1
# 70      1
# 42      1
# 45      1
# 115     1
# 120     1
# 125     1
# 140     1
# 150     1
# Name: count, dtype: int64

# %%
#solt_values -> ye values ko sort karne me kaam ata hai
x.sort_values("runs",inplace=True)
x
# Out:
#           runs
# match_no
# 8            0
# 87           0
# 93           0
# 91           0
# 206          0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %%
#sort_index(inplace =) -> ye index ko sort karega

n.sort_index(inplace = True)

# %%
# .count() ye total no of item's ko calculate kare ke return karega but ye missing values ko ignore karega

n.count()
# Out:
# MovieName              149
# Budget                 149
# BoxOfficeCollection    149
# YoutubeViews           149
# dtype: int64

# %%
#.size -> ye total no of item's ko calculate kar ke return karega but ye missing valus ko bhi calculate karega

n.size
# Out:
# 596

# %%
x
# Out:
#           runs
# match_no
# 8            0
# 87           0
# 93           0
# 91           0
# 206          0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %%
x.sum()
x.product()
# Out:
# runs    0
# dtype: int64

# %%
#mean, median, mode, std, var

print(x.mean())
print(x.median())
print(x.mode())
print(x.std())
print(x.var())
# Out:
# runs    30.855814
# dtype: float64
# runs    24.0
# dtype: float64
#    runs
# 0     0
# runs    26.229801
# dtype: float64
# runs    688.002478
# dtype: float64

# %%
x.min()
x.max()
# Out:
# runs    113
# dtype: int64

# %%
#describe()

x.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %%
#
n.describe()
# Out:
#            Budget  BoxOfficeCollection  YoutubeViews
# count  149.000000           149.000000  1.490000e+02
# mean    29.442953            55.667248  3.337920e+06
# std     28.237981            94.494531  3.504407e+06
# min      2.000000             0.010000  4.354000e+03
# 25%     11.000000             8.780000  1.076591e+06
# 50%     21.000000            28.000000  2.375050e+06
# 75%     35.000000            57.450000  4.550051e+06
# max    150.000000           735.000000  2.317107e+07

# %%
#series indexing

x = pd.Series([i for i in range(9)])
x[1]
# Out:
# np.int64(1)

# %%
#series with python functionalities

#len/type/dir/sorted/max/min
print(len(n))
print(type(n))
print("dir ",dir(n))
print("Sorteed: ", sorted(n))
print("max: ", max(n))
print("min: " ,min(n))
# Out:
# 149
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
#type conversiion

list(n)
# Out:
# ['MovieName', 'Budget', 'BoxOfficeCollection', 'YoutubeViews']

# %%
dict(n)
# Out:
# {'MovieName': SlNo
#  1                        2States
#  2                     TableNo.21
#  3                AmitSahniKiList
#  4                RajdhaniExpress
#  5                    BobbyJasoos
#                   ...
#  145              DumLagaKeHaisha
#  146                         NH10
#  147    DilliwaliZaalimGirlfriend
#  148                     Hunterrr
#  149                Kochadaiiyaan
#  Name: MovieName, Length: 149, dtype: object,
#  'Budget': SlNo
#  1       36
#  2       10
#  3       10
#  4        7
#  5       18
#        ...
#  145     15
#  146     13
#  147     32
#  148      5
#  149    150
#  Name: Budget, Length: 149, dtype: int64,
#  'BoxOfficeCollection': SlNo
#  1      104.00
#  2       12.00
#  3        4.00
#  4        0.35
#  5       10.80
#          ...
#  145     30.00
#  146     32.10
#  147     12.00
#  148     11.89
#  149    120.00
#  Name: BoxOfficeCollection, Length: 149, dtype: float64,
#  'YoutubeViews': SlNo
#  1      8576361
# ...

# %%
#membership operator(in or not in)

'2 States (2014 film)' in n.values
# Out:
# False

# %%
for i in n.MovieName:
  print(i)
# Out:
# 2States
# TableNo.21
# AmitSahniKiList
# RajdhaniExpress
# BobbyJasoos
# Citylights
# Daawat-E-Ishq
# MatruKiBijleeKaMandola
# DedhIshqiya
# Gangoobai
# Dishkiyaoon
# Inkaar
# EkVillain
# MumbaiMirror
# Entertainment
# Bandook
# Race2
# Filmistaan
# FindingFanny
# Fugly
# David
# GulaabGang
# Gunday
# Haider
# HappyEnding
# Special26
# HappyNewYear
# ABCD_AnyBodyCanDance
# HateStory2
# HawaaHawaai
# Heartless
# Murder3
# Heropanti
# KaiPoChe!
# Highway
# ZillaGhaziabad
# Holiday
# HumptySharmaKiDulhania
# TheAttacksof26/11
# Humshakals
# Saheb,BiwiAurGangsterReturns
# JaiHo
# Khoobsurat
# Kick
# 3G
# KillDil
# MereDadKiMaruti
# JollyLLB
# Koyelaanchal
# KyaDilliKyaLahore
# LekarHumDeewanaDil
# Aatma
# MainTeraHero
# SonaSpa
# Himmatwala
# Manjunath
# Mardaani
# ChashmeBaddoor
# MaryKom
# NautankiSaala
# Mastram
# Commando-AOneManArmy
# EkThiDaayan
# MissLovely
# Aashiqui2
# OTeri
# OnebyTwo
# PuraniJeans
# ShootoutatWadala
# Queen
# BombayTalkies
# RaginiMMS2
# GoGoaGone
# ...

# %%
#Arithmatic operator
100 * x
# Out:
# 0      0
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# 6    600
# 7    700
# 8    800
# dtype: int64

# %%
x >= 50
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool
