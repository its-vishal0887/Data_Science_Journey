# %% [markdown]
# Print Function

# %%
print('hello', 1, 4, True, sep = '/')
# Out:
# hello/1/4/True

# %%
#end= funtion
print("hello")
print("world")
# Out:
# hello
# world

# %% [markdown]
# both print variable print output seprately
# when we want in single line both print output
# then use 'end =' varibale

# %%
#eg:
print("hello", end = '-')
print("world")
# Out:
# hello-world

# %% [markdown]
# Data Types in python

# %%
#integer
print(5)
#python can handle max size of integer is :->
print(1e308) #above 308 it's infinite
# Out:
# 5
# 1e+308

# %%
#Decimal / Float
print(8.9)
#decimal ki integer ke baad floating number ki ranhe 7e308 tak hai
print(7e307)
# Out:
# 8.9
# 7e+307

# %%
#bool data type
print(True)
print(False)
# Out:
# True
# False

# %%
#Text / string
print("Hello World!")
#in python there are no char
# Out:
# Hello World!

# %%
#Complex Number
print(5 + 6j)
# Out:
# (5+6j)

# %%
#Array/List[]
print([10,20,30,40])
# Out:
# [10, 20, 30, 40]

# %%
#Tuple
print((5,8,7,6,3))
# Out:
# (5, 8, 7, 6, 3)

# %%
#sets
print({1,2,3,4})
# Out:
# {1, 2, 3, 4}

# %%
#Dictionary
print({'Name':'Vishal', 'Name1':'Dhiresh'})
# Out:
# {'Name': 'Vishal', 'Name1': 'Dhiresh'}

# %%
input("Apna Naam Batao")
# Out:
# 'Vishal'

# %%
input("enter FNumber: ")
# Out:
# '56'

# %%
fnum = int(input("Enter FNum: ")) #if int nahi likha to unversally vo string me return hoga
snum = int(input("Enter Second Number:"))
result = fnum + snum
print(type(fnum), type(snum))
print(result)
# Out:
# <class 'int'> <class 'int'>
# 25

# %% [markdown]
# Type Conversion

# %% [markdown]
# Implicit Vs Explicit

# %%
print(5*6.5)
print(type(5), type(6.5))
# Out:
# 32.5
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 print(5*6.5)
#       2 print(type(5), type(6.5))
# ----> 3 int(Q)
#
# NameError: name 'Q' is not defined
