# %% [markdown]
# <a href="https://colab.research.google.com/github/its-vishal0887/Python_Journey/blob/main/opp_part_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Aggrigation
class Customer:
    def __init__(self, name, gender, address):
        self.name = name
        self.gender = gender
        self.address = address

    def print_address(self):
        print(self.name, self.gender, self.address.getCity(), self.address.pin, self.address.state)
        #print(self.address.city, self.address.state, self.address.pin)

    def edit_profile(self, new_name, new_gender, new_city, new_pin, new_satae):
      self.name = new_name
      self.gender = new_gender
      self.address .edit_address(new_city, new_pin, new_satae)



class Address:
    def __init__(self, city, pin, state):
        self.__city = city
        self.pin = pin
        self.state = state

    def getCity(self):
        return self.__city

    def edit_address(self, new_city, new_pin, new_state):
          self.__city = new_city
          self.pin = new_pin
          self.state = new_state

# %%
add = Address("Jintur",431509, "Maharashtra")
c = Customer("Vishal", "Male", add)
c.edit_profile("Pushpa", "male", "Guntur", 431506, "Maharashtra")
c.print_address()
# Out:
# Pushpa male Guntur 431506 Maharashtra

# %%
#Inheritance syntax
class User: #parent class
  def __init__(self):
    self.name = "Vishal"

  def login(self):
    print("login Successfully")

class Student(User): #child class
  # def __init__(self):
  #   super().__init__() # Call the parent class's __init__ method
  #   self.roll_no = 33

  def enroll(self):
    print("Enrolled Successfully")


# Instantiate objects outside the class definition
u = User()
s = Student()

print(s.name)
# Out:
# Vishal

# %%
class Parent:
  def __init__(self, num):
    self.__num = num

  def get_num(self):
    return self.__num

class Child(Parent):

  def show(self):
    print("This is in child class")

son = Child(100)
print(son.get_num())

son.show()
# Out:
# 100
# This is in child class

# %%
#methode overriding
class Phone:
  def __init__(self, price, brand, camera):
    print("Inside phone constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("BYing A Phone..!")

class SmartPhone(Phone):
  def buy(self):
    print("Bying a smartphone..!")


s = SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Bying a smartphone..!

# %%
#Super keyWord
#super() is way to use parent class methode's
class Phone:
  def __init__(self, price, brand, camera):
    print("Inside phone constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("BYing A Phone..!")

class SmartPhone(Phone):
  def buy(self):
    print("Bying a smartphone..!")
    super().buy() #Due to this keyWord parent class ka buy methode bhi call hua



s = SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Bying a smartphone..!
# BYing A Phone..!

# %%
#super -> constructor

class Phone:
  def __init__(self, price, brand, camera):
    print("Inside phone constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera


class SmartPhone(Phone):
  def __init__(self, price , brand, camera, os , ram):
    super().__init__(price, brand, camera) #yaha se parent ka constructor call hua
    self.os = os
    self.ram = ram
    print("Inside smartphone constructor")


s = SmartPhone(20000, "Samsung", 13, "Android", 2)

print(s.os)
print(s.brand)
# Out:
# Inside phone constructor
# Inside smartphone constructor
# Android
# Samsung

# %%
#Super keyWord
#super() is way to use parent class methode's
class Phone:
  def __init__(self, price, brand, camera):
    print("Inside phone constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("BYing A Phone..!")

class SmartPhone(Phone):
  def buy(self):
    print("Bying a smartphone..!")
    print(super().brand)


s = SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Bying a smartphone..!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1091176385.py in <cell line: 0>()
#      20 s = SmartPhone(20000, "Apple", 13)
#      21
# ---> 22 s.buy()
#
# /tmp/ipython-input-1091176385.py in buy(self)
#      14   def buy(self):
#      15     print("Bying a smartphone..!")
# ---> 16     print(super().brand) #Due to this keyWord parent class ka buy methode bhi call hua
#      17
#      18
#
# AttributeError: 'super' object has no attribute 'brand'

# %%
class A:
  def m1(self):
    return 30

class B(A):
  def m1(self):
    return 20

  def m2(self):
    return 40

class C(B):
  def m2(self):
    return 20

obj1 = A()
obj2 = B()
obj3 = C()

print(obj1.m1() + obj3.m1() +obj3.m2() )
# Out:
# 70

# %%
class A:
  def m1(self):
    return 20


class B(A):

  def m1(self):
    val = super().m1()+30
    return val

class C(B):
  def m1(self):
    val = self.m1() + 20
    return val


obj = C()
print(obj.m1())
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipython-input-3874270775.py in <cell line: 0>()
#      17
#      18 obj = C()
# ---> 19 print(obj.m1())
#
# /tmp/ipython-input-3874270775.py in m1(self)
#      12 class C(B):
#      13   def m1(self):
# ---> 14     val = self.m1() + 20
#      15     return val
#      16
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipython-input-3874270775.py in m1(self)
#      12 class C(B):
#      13   def m1(self):
# ---> 14     val = self.m1() + 20
#      15     return val
#      16
#
# RecursionError: maximum recursion depth exceeded
